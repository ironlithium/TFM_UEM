# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# PROBLEMA OVERFITTING CNN LSTM

# %% [markdown]
# sin dropout tras embedding

# %%
import matplotlib.pyplot as plt

# Datos de entrenamiento y validación
epochs = list(range(1, 6))  # Épocas del 1 al 5
accuracy = [0.7767, 0.8528, 0.8756, 0.8971, 0.9135]  # Precisión en entrenamiento
val_accuracy = [0.8412, 0.8504, 0.8494, 0.8470, 0.8432]  # Precisión en validación
loss = [0.4507, 0.3296, 0.2850, 0.2443, 0.2103]  # Pérdida en entrenamiento
val_loss = [0.3535, 0.3495, 0.3860, 0.4627, 0.5313]  # Pérdida en validación

# Crear una figura con dos subgráficas
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 10))

# Gráfica de precisión
ax1.plot(epochs, accuracy, 'bo-', label='Entrenamiento')
ax1.plot(epochs, val_accuracy, 'ro-', label='Validación')
ax1.set_title('Precisión por Época')
ax1.set_xlabel('Épocas')
ax1.set_ylabel('Precisión')
ax1.legend()
ax1.grid()

# Gráfica de pérdida
ax2.plot(epochs, loss, 'bo-', label='Entrenamiento')
ax2.plot(epochs, val_loss, 'ro-', label='Validación')
ax2.set_title('Pérdida por Época')
ax2.set_xlabel('Épocas')
ax2.set_ylabel('Pérdida')
ax2.legend()
ax2.grid()

# Mostrar las gráficas
plt.tight_layout()
plt.show()

# %% [markdown]
# con dropout tras embedding

# %%
import matplotlib.pyplot as plt

# Datos de las métricas por época
epochs = list(range(1, 8))  # Épocas de 1 a 7
accuracy = [0.7556, 0.8350, 0.8532, 0.8629, 0.8737, 0.8800, 0.8853]  # Precisión de entrenamiento
val_accuracy = [0.8382, 0.8470, 0.8522, 0.8525, 0.8524, 0.8515, 0.8486]  # Precisión de validación
loss = [0.4809, 0.3597, 0.3265, 0.3051, 0.2885, 0.2754, 0.2627]  # Pérdida de entrenamiento
val_loss = [0.3605, 0.3462, 0.3401, 0.3414, 0.3508, 0.3520, 0.3529]  # Pérdida de validación

# Crear la figura con dos subgráficas
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 10))

# Gráfica de precisión
ax1.plot(epochs, accuracy, 'bo-', label='Precisión de Entrenamiento')
ax1.plot(epochs, val_accuracy, 'ro-', label='Precisión de Validación')
ax1.set_title('Precisión por Época')
ax1.set_xlabel('Épocas')
ax1.set_ylabel('Precisión')
ax1.legend()
ax1.grid(True)

# Gráfica de pérdida
ax2.plot(epochs, loss, 'bo-', label='Pérdida de Entrenamiento')
ax2.plot(epochs, val_loss, 'ro-', label='Pérdida de Validación')
ax2.set_title('Pérdida por Época')
ax2.set_xlabel('Épocas')
ax2.set_ylabel('Pérdida')
ax2.legend()
ax2.grid(True)

# Mostrar las gráficas
plt.tight_layout()
plt.show()

# %% [markdown]
# dropout 0,5 después de capa convolucional

# %%
import matplotlib.pyplot as plt

# Datos de las métricas por época
epochs = list(range(1, 17))  # Épocas de 1 a 16
accuracy = [0.7425, 0.8185, 0.8305, 0.8401, 0.8447, 0.8478, 0.8534, 0.8529, 0.8573, 0.8569, 0.8564, 0.8633, 0.8617, 0.8644, 0.8652, 0.8666]  # Precisión de entrenamiento
val_accuracy = [0.8290, 0.8376, 0.8426, 0.8470, 0.8488, 0.8506, 0.8506, 0.8543, 0.8540, 0.8535, 0.8550, 0.8558, 0.8559, 0.8544, 0.8551, 0.8547]  # Precisión de validación
loss = [0.5038, 0.3897, 0.3671, 0.3554, 0.3450, 0.3391, 0.3306, 0.3271, 0.3209, 0.3181, 0.3175, 0.3103, 0.3107, 0.3058, 0.3038, 0.3022]  # Pérdida de entrenamiento
val_loss = [0.3731, 0.3563, 0.3508, 0.3367, 0.3373, 0.3300, 0.3286, 0.3280, 0.3282, 0.3267, 0.3283, 0.3306, 0.3225, 0.3318, 0.3260, 0.3265]  # Pérdida de validación

# Crear la figura con dos subgráficas
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 10))

# Gráfica de precisión
ax1.plot(epochs, accuracy, 'bo-', label='Precisión de Entrenamiento')
ax1.plot(epochs, val_accuracy, 'ro-', label='Precisión de Validación')
ax1.set_title('Precisión por Época')
ax1.set_xlabel('Épocas')
ax1.set_ylabel('Precisión')
ax1.legend()
ax1.grid(True)

# Gráfica de pérdida
ax2.plot(epochs, loss, 'bo-', label='Pérdida de Entrenamiento')
ax2.plot(epochs, val_loss, 'ro-', label='Pérdida de Validación')
ax2.set_title('Pérdida por Época')
ax2.set_xlabel('Épocas')
ax2.set_ylabel('Pérdida')
ax2.legend()
ax2.grid(True)

# Mostrar las gráficas
plt.tight_layout()
plt.show()

# %% [markdown]
# dropout 0,5 después de capa lstm

# %%
import matplotlib.pyplot as plt

# Datos obtenidos del entrenamiento
epochs = list(range(1, 9))  # Épocas del 1 al 8
accuracy = [0.7450, 0.8337, 0.8507, 0.8618, 0.8699, 0.8781, 0.8833, 0.8900]  # Precisión en entrenamiento
val_accuracy = [0.8364, 0.8455, 0.8522, 0.8530, 0.8551, 0.8520, 0.8523, 0.8540]  # Precisión en validación
loss = [0.4951, 0.3656, 0.3337, 0.3122, 0.2955, 0.2823, 0.2719, 0.2576]  # Pérdida en entrenamiento
val_loss = [0.3620, 0.3472, 0.3356, 0.3326, 0.3324, 0.3420, 0.3524, 0.3490]  # Pérdida en validación

# Crear una figura con dos subgráficas
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 10))

# Gráfica de precisión
ax1.plot(epochs, accuracy, 'bo-', label='Entrenamiento')
ax1.plot(epochs, val_accuracy, 'ro-', label='Validación')
ax1.set_title('Precisión por Época')
ax1.set_xlabel('Épocas')
ax1.set_ylabel('Precisión')
ax1.legend()
ax1.grid()

# Gráfica de pérdida
ax2.plot(epochs, loss, 'bo-', label='Entrenamiento')
ax2.plot(epochs, val_loss, 'ro-', label='Validación')
ax2.set_title('Pérdida por Época')
ax2.set_xlabel('Épocas')
ax2.set_ylabel('Pérdida')
ax2.legend()
ax2.grid()

# Mostrar las gráficas
plt.tight_layout()
plt.show()

# %% [markdown]
# dropout 0,5 después de capa densa

# %%
import matplotlib.pyplot as plt

# Datos de las métricas por época
epochs = list(range(1, 11))  # Épocas de 1 a 10
accuracy = [0.7522, 0.8337, 0.8525, 0.8607, 0.8693, 0.8776, 0.8831, 0.8880, 0.8950, 0.8953]  # Precisión de entrenamiento
val_accuracy = [0.8375, 0.8455, 0.8493, 0.8533, 0.8547, 0.8547, 0.8548, 0.8544, 0.8534, 0.8519]  # Precisión de validación
loss = [0.4953, 0.3667, 0.3339, 0.3134, 0.2970, 0.2824, 0.2706, 0.2599, 0.2489, 0.2420]  # Pérdida de entrenamiento
val_loss = [0.3614, 0.3446, 0.3361, 0.3379, 0.3481, 0.3435, 0.3485, 0.3797, 0.3788, 0.3966]  # Pérdida de validación

# Crear la figura con dos subgráficas
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 10))

# Gráfica de precisión
ax1.plot(epochs, accuracy, 'bo-', label='Precisión de Entrenamiento')
ax1.plot(epochs, val_accuracy, 'ro-', label='Precisión de Validación')
ax1.set_title('Precisión por Época')
ax1.set_xlabel('Épocas')
ax1.set_ylabel('Precisión')
ax1.legend()
ax1.grid(True)

# Gráfica de pérdida
ax2.plot(epochs, loss, 'bo-', label='Pérdida de Entrenamiento')
ax2.plot(epochs, val_loss, 'ro-', label='Pérdida de Validación')
ax2.set_title('Pérdida por Época')
ax2.set_xlabel('Épocas')
ax2.set_ylabel('Pérdida')
ax2.legend()
ax2.grid(True)

# Mostrar las gráficas
plt.tight_layout()
plt.show()

# %% [markdown]
# batchnormalizatoin despues de capa convolucional y dropout de 0,3

# %%
import matplotlib.pyplot as plt

# Datos de las métricas por época
epochs = list(range(1, 18))  # Épocas de 1 a 17
accuracy = [0.7380, 0.8230, 0.8373, 0.8430, 0.8500, 0.8563, 0.8600, 0.8625, 0.8649,
            0.8685, 0.8699, 0.8717, 0.8748, 0.8751, 0.8769, 0.8783, 0.8792]  # Precisión de entrenamiento
val_accuracy = [0.8312, 0.8438, 0.8435, 0.8467, 0.8501, 0.8506, 0.8524, 0.8515,
                0.8532, 0.8535, 0.8518, 0.8547, 0.8557, 0.8559, 0.8552, 0.8547, 0.8528]  # Precisión de validación
loss = [0.5056, 0.3871, 0.3572, 0.3439, 0.3327, 0.3200, 0.3154, 0.3067, 0.3015,
        0.2990, 0.2935, 0.2882, 0.2835, 0.2821, 0.2790, 0.2749, 0.2736]  # Pérdida de entrenamiento
val_loss = [0.3712, 0.3526, 0.3558, 0.3473, 0.3453, 0.3414, 0.3438, 0.3507,
            0.3435, 0.3403, 0.3503, 0.3534, 0.3463, 0.3588, 0.3527, 0.3482, 0.3484]  # Pérdida de validación

# Crear la figura con dos subgráficas
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 10))

# Gráfica de precisión
ax1.plot(epochs, accuracy, 'bo-', label='Precisión de Entrenamiento')
ax1.plot(epochs, val_accuracy, 'ro-', label='Precisión de Validación')
ax1.set_title('Precisión por Época')
ax1.set_xlabel('Épocas')
ax1.set_ylabel('Precisión')
ax1.legend()
ax1.grid(True)

# Gráfica de pérdida
ax2.plot(epochs, loss, 'bo-', label='Pérdida de Entrenamiento')
ax2.plot(epochs, val_loss, 'ro-', label='Pérdida de Validación')
ax2.set_title('Pérdida por Época')
ax2.set_xlabel('Épocas')
ax2.set_ylabel('Pérdida')
ax2.legend()
ax2.grid(True)

# Mostrar las gráficas
plt.tight_layout()
plt.show()

# %% [markdown]
# batch y 03 para filtro de 256

# %%
import matplotlib.pyplot as plt

# Datos de las métricas por época
epochs = list(range(1, 12))  # Épocas de 1 a 11
accuracy = [0.7381, 0.8285, 0.8443, 0.8523, 0.8601, 0.8679, 0.8742, 0.8779,
            0.8824, 0.8860, 0.8901]  # Precisión de entrenamiento
val_accuracy = [0.8376, 0.8440, 0.8477, 0.8508, 0.8505, 0.8521, 0.8500, 0.8540,
                0.8537, 0.8520, 0.8484]  # Precisión de validación
loss = [0.5038, 0.3764, 0.3443, 0.3286, 0.3128, 0.2975, 0.2858, 0.2764,
        0.2680, 0.2594, 0.2545]  # Pérdida de entrenamiento
val_loss = [0.3667, 0.3529, 0.3480, 0.3506, 0.3509, 0.3443, 0.3616, 0.3531,
            0.3630, 0.3741, 0.3773]  # Pérdida de validación

# Crear la figura con dos subgráficas
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 10))

# Gráfica de precisión
ax1.plot(epochs, accuracy, 'bo-', label='Precisión de Entrenamiento')
ax1.plot(epochs, val_accuracy, 'ro-', label='Precisión de Validación')
ax1.set_title('Precisión por Época')
ax1.set_xlabel('Épocas')
ax1.set_ylabel('Precisión')
ax1.legend()
ax1.grid(True)

# Gráfica de pérdida
ax2.plot(epochs, loss, 'bo-', label='Pérdida de Entrenamiento')
ax2.plot(epochs, val_loss, 'ro-', label='Pérdida de Validación')
ax2.set_title('Pérdida por Época')
ax2.set_xlabel('Épocas')
ax2.set_ylabel('Pérdida')
ax2.legend()
ax2.grid(True)

# Mostrar las gráficas
plt.tight_layout()
plt.show()

# %% [markdown]
# dropout 0,5 para filtro 256

# %%
import matplotlib.pyplot as plt

# Datos de las métricas por época
epochs = list(range(1, 12))  # Épocas de 1 a 11
accuracy = [0.7539, 0.8292, 0.8476, 0.8558, 0.8625, 0.8703, 0.8756, 0.8782,
            0.8813, 0.8873, 0.8874]  # Precisión de entrenamiento
val_accuracy = [0.8359, 0.8472, 0.8521, 0.8553, 0.8553, 0.8583, 0.8597, 0.8611,
                0.8611, 0.8587, 0.8593]  # Precisión de validación
loss = [0.4834, 0.3713, 0.3395, 0.3220, 0.3102, 0.2964, 0.2853, 0.2743,
        0.2693, 0.2602, 0.2576]  # Pérdida de entrenamiento
val_loss = [0.3636, 0.3463, 0.3360, 0.3273, 0.3301, 0.3371, 0.3373, 0.3391,
            0.3462, 0.3458, 0.3581]  # Pérdida de validación

# Crear la figura con dos subgráficas
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 10))

# Gráfica de precisión
ax1.plot(epochs, accuracy, 'bo-', label='Precisión de Entrenamiento')
ax1.plot(epochs, val_accuracy, 'ro-', label='Precisión de Validación')
ax1.set_title('Precisión por Época')
ax1.set_xlabel('Épocas')
ax1.set_ylabel('Precisión')
ax1.legend()
ax1.grid(True)

# Gráfica de pérdida
ax2.plot(epochs, loss, 'bo-', label='Pérdida de Entrenamiento')
ax2.plot(epochs, val_loss, 'ro-', label='Pérdida de Validación')
ax2.set_title('Pérdida por Época')
ax2.set_xlabel('Épocas')
ax2.set_ylabel('Pérdida')
ax2.legend()
ax2.grid(True)

# Mostrar las gráficas
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Datos de las métricas para las 12 épocas proporcionadas
epochs_new = list(range(1, 13))  # Épocas de 1 a 12
accuracy_new = [
    0.7507, 0.8268, 0.8406, 0.8489, 0.8564, 0.8621, 0.8654, 0.8666, 0.8697,
    0.8711, 0.8720, 0.8774
]  # Precisión de entrenamiento
val_accuracy_new = [
    0.8283, 0.8419, 0.8467, 0.8512, 0.8537, 0.8558, 0.8565, 0.8573, 0.8576,
    0.8520, 0.8573, 0.8544
]  # Precisión de validación
loss_new = [
    0.4893, 0.3769, 0.3505, 0.3351, 0.3232, 0.3140, 0.3054, 0.2988, 0.2943,
    0.2908, 0.2871, 0.2794
]  # Pérdida de entrenamiento
val_loss_new = [
    0.3763, 0.3513, 0.3473, 0.3336, 0.3293, 0.3244, 0.3254, 0.3359, 0.3262,
    0.3464, 0.3335, 0.3406
]  # Pérdida de validación

# Crear la figura con dos subgráficas
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 10))

# Gráfica de precisión
ax1.plot(epochs_new, accuracy_new, 'bo-', label='Precisión de Entrenamiento')
ax1.plot(epochs_new, val_accuracy_new, 'ro-', label='Precisión de Validación')
ax1.set_title('Precisión por Época (Nuevos Datos)')
ax1.set_xlabel('Épocas')
ax1.set_ylabel('Precisión')
ax1.legend()
ax1.grid(True)

# Gráfica de pérdida
ax2.plot(epochs_new, loss_new, 'bo-', label='Pérdida de Entrenamiento')
ax2.plot(epochs_new, val_loss_new, 'ro-', label='Pérdida de Validación')
ax2.set_title('Pérdida por Época (Nuevos Datos)')
ax2.set_xlabel('Épocas')
ax2.set_ylabel('Pérdida')
ax2.legend()
ax2.grid(True)

# Mostrar las gráficas
plt.tight_layout()
plt.show()

# %% [markdown]
# GRÁFICA DEL TIEMPO

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Leer el archivo CSV
df = pd.read_csv('/content/drive/MyDrive/multiTimeline.csv', parse_dates=['Mes'])

# Convertir la columna 'Mes' a tipo datetime
df['Mes'] = pd.to_datetime(df['Mes'])

# Graficar
plt.figure(figsize=(12, 6))
plt.plot(df['Mes'], df['sentiment analysis'])
plt.title('Búsquedas de "sentiment analysis" a lo largo del tiempo')
plt.xlabel('Fecha')
plt.ylabel('Número de Búsquedas')
plt.xticks(rotation=45)
plt.grid()
plt.show()
